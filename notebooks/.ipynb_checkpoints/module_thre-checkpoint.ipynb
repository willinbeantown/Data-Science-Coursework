# %%
# pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/16.5 MB 16.7 MB/s eta 0:00:01
#    ------------ --------------------------- 5.2/16.5 MB 21.4 MB/s eta 0:00:01
#    ------------------------ --------------- 10.2/16.5 MB 22.5 MB/s eta 0:00:01
#    -------------------------------------- - 15.7/16.5 MB 23.5 MB/s eta 0:00:01
#    ---------------------------------------- 16.5/16.5 MB 22.2 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Connect to MySQL Server
import mysql.connector

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="127.0.0.1",
    port=3306,
    user="your_username",
    password="your_password",
    database="your_database"
)

cursor = conn.cursor()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:354, in CMySQLConnection._open_connection(self)
#     353 try:
# --> 354     self._cmysql.connect(**cnx_kwargs)
#     355     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Can't connect to MySQL server on '127.0.0.1:3306' (10061)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[10], line 3
#       1 import mysql.connector
# ----> 3 conn = mysql.connector.connect(
#       4     host="127.0.0.1",
#       5     port=3306,
#       6     user="your_username",
#       7     password="your_password",
#       8     database="your_database"
#       9 )
#      11 cursor = conn.cursor()
#
# ...

# %%
# Create a database named `qctestdb`

# %%
# Create a tanmes named `testresults` with 3 columns.
# Use `executemany` to populate table

# %% [markdown]
# |plate|testresultes|zip|
# |-|-|-|
# |1001|ABC|93722

# %%
# primary_key == 'platet, type = int, is not null

# testresults, type = str, is not null

# zip, type = int, is not null
