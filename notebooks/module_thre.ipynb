# %%
# pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/16.5 MB 16.7 MB/s eta 0:00:01
#    ------------ --------------------------- 5.2/16.5 MB 21.4 MB/s eta 0:00:01
#    ------------------------ --------------- 10.2/16.5 MB 22.5 MB/s eta 0:00:01
#    -------------------------------------- - 15.7/16.5 MB 23.5 MB/s eta 0:00:01
#    ---------------------------------------- 16.5/16.5 MB 22.2 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Connect to MySQL Server
import mysql.connector

# %%
# import mysql.connector

conn = mysql.connector.connect(
    host="127.0.0.1",
    port=3306,
    user="awrjr",
    password="BLUEgreen555"
)

cursor = conn.cursor()

# %%
# Create a database named `qctestdb`
cursor = conn.cursor()
cursor.execute("CREATE DATABASE IF NOT EXISTS qctestdb")
cursor.execute("SHOW DATABASES")

for db in cursor:
    print(db)
# Out:
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('qctestdb',)
# ('sys',)

# %%
conn = mysql.connector.connect(
    host="127.0.0.1",
    port=3306,
    user="awrjr",
    password="BLUEgreen555",
    database="qctestdb"
)

# %%
cursor = conn.cursor()

# %%
create_table_sql = """
CREATE TABLE IF NOT EXISTS customers (
    primary_key VARCHAR(50) PRIMARY KEY,
    testresults INT NOT NULL,
    zip VARCHAR(50) NOT NULL,
);
"""

cursor.execute(create_table_sql)
conn.commit()

print("Table created!")

# %%
cursor.close()
conn.close()

# %%
# Create a table named `testresults` with 3 columns.
# Use `executemany` to populate table

# %% [markdown]
# |plate|testresultes|zip|
# |-|-|-|
# |1001|ABC|93722

# %%
# primary_key == 'platet, type = int, is not null

# testresults, type = str, is not null

# zip, type = int, is not null
