# %%
# Connect to MySQL Server
import mysql.connector

# %%
# CONNECT TO MYSQL
conn = mysql.connector.connect(
    host="127.0.0.1",
    port=3306,
    user="awrjr",
    password="BLUEgreen555",
    database="qctestdb"
)

# Create a database named `qctestdb`
cursor = conn.cursor()
cursor.execute("CREATE DATABASE IF NOT EXISTS qctestdb")

# %%
cursor.execute("SHOW DATABASES")
for db in cursor:
    print(db)
# Out:
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('qctestdb',)
# ('sys',)

# %%
# cursor.execute("""
# CREATE TABLE IF NOT EXISTS qctestdb (
#     plate INT PRIMARY KEY,
#     testresults VARCHAR(255),
#     zip INT
# )
# """)
# conn.commit()

# %%
cursor.execute("DESCRIBE qctestdb")
for row in cursor:
    print(row)
# Out:
# ('plant', 'int', 'NO', 'PRI', None, '')
# ('testresults', 'varchar(255)', 'YES', '', None, '')
# ('zip', 'int', 'YES', '', None, '')

# %%
from pandas import read_csv

data = read_csv("data.csv")

# CONVERT TO TUPLE TO LOADING TO SQL
data = list(data.itertuples(index=False, name=None))

# print(data)

# %%
# insert_sql = """
# INSERT INTO qctestdb (plant, testresults, zip)
# VALUES (%s, %s, %s)
# """

# cursor.executemany(insert_sql, data)
# conn.commit()

# print(f"{cursor.rowcount} rows inserted")

# %%
# cursor.close()
# conn.close()

# %%
cursor.execute("SELECT * FROM qctestdb")

rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1001, 'B1234PABQ50D20230908', 93722)
# (1002, 'B1234PABQ0050D20230908B5678PXYQ0030D20230909', 1960)
# (1006, 'B1234PABQ0050D20230908', 2703)
# (1007, 'B2021PGEQ25D20230103', 77433)
# (1008, 'B4521PABQ56D20230315', 33023)

# %%
cursor.execute("SELECT testresults, zip FROM qctestdb WHERE plant = 1001")

rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# ('B1234PABQ50D20230908', 93722)

# %%
from pandas import read_sql

# %%
df = read_sql("SELECT * FROM qctestdb", conn)
# Out:
# C:\Users\awill\AppData\Local\Temp\ipykernel_5752\2103099061.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = read_sql("SELECT * FROM qctestdb", conn)

# %%
df
# Out:
#    plant                                   testresults    zip
# 0   1001                          B1234PABQ50D20230908  93722
# 1   1002  B1234PABQ0050D20230908B5678PXYQ0030D20230909   1960
# 2   1006                        B1234PABQ0050D20230908   2703
# 3   1007                          B2021PGEQ25D20230103  77433
# 4   1008                          B4521PABQ56D20230315  33023

# %%
# Create a table named `testresults` with 3 columns.
# Use `executemany` to populate table

# %% [markdown]
# |plate|testresultes|zip|
# |-|-|-|
# |1001|ABC|93722

# %%
# primary_key == 'platet, type = int, is not null

# testresults, type = str, is not null

# zip, type = int, is not null
