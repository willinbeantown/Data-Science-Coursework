# %% [markdown]
# ### INTRODUCTION TO USEFUL PYTHON LIBRARIES
#
# A small iPython notebook using `math`, `pandas`, and `random` to introduce statistical formula for **Mean**, **Standard Deviation**, **Sample Standard Deviation**, **Variance**, _ _ _ , and to practice Python in a Jupyter Notebook.

# %%
from pandas import read_csv
from math import sqrt

data_df = read_csv("data.csv")

# Find Variance for Specified Column
mean = sum(data_df["Yes"].to_list())/len(data_df)
standard_dev = sqrt((1/(len(data_df)-1))*mean)
yes_variance = standard_dev ** 2

yes_variance
# Out:
# 2.9642857142857144

# %%
# QUESTION 6
# SD of patient's age & Variance
standard_dev2 = math.sqrt((1/100)*65)
print(standard_dev2)

variance = standard_dev2 ** 2
print(variance)
# Out:
# 0.806225774829855
# 0.6500000000000001

# %%
# QUESTION 12
other_mean = standard_dev ** 2
standard_dev = sqrt((1/len(data_df))*mean)

standard_dev
# Out:
# 1.6802170251787951
