# %%
import math
import pandas

# %%
data = "data.csv"

# %%
data_df = pandas.read_csv(data)

# %%
# QUESTION 4
# What is the Variance of the 'yes' responses for all 21 survey questions?
mean = sum(data_df["Yes"].to_list())/len(data_df)
standard_dev = math.sqrt((1/(len(data_df)-1))*mean)
yes_variance = standard_dev ** 2

print(yes_variance)
# Out:
# 2.9642857142857144

# %%
# QUESTION 6
# SD of patient's age & Variance
standard_dev2 = math.sqrt((1/100)*65)
print(standard_dev2)

variance = standard_dev2 ** 2
print(variance)
# Out:
# 0.806225774829855
# 0.025849492695058388
# 0.6500000000000001

# %%
# QUESTION 12
other_mean = standard_dev ** 2
standard_dev = math.sqrt((1/len(data_df))*mean)
